# %% [markdown]
# # DataFrame to MySQL Database

# %%
import pandas as pd

# %%
#Installing pymysql library
# pip install pymysql

# %%
#These two libraries are required for setting up connection between pandas and mysql database
from sqlalchemy import create_engine
import pymysql

#Mysql+pymysql are used together after that set connection
#username=root, then colon, password=cs36, then your host that is by defaul localhost and then name of the 
#database
conn = create_engine('mysql+pymysql://root:cs36@localhost/civil')

# %%
#Reading dept name from databes civil and then converting it into the dataframe
df = pd.read_sql('dept', conn)
df.head()
# Out:
#    deptno  deptname
# 0     100  Research
# 1     102        CS
# 2     103        IT
# 3     104        SW

# %%
#Reading data set
eda = pd.read_csv(r'F:\Data Science Course\Datasets\automobileEDA.csv')
eda.head()
# Out:
#    Unnamed: 0  symboling  normalized-losses         make aspiration  \
# 0           0          3                122  alfa-romero        std
# 1           1          3                122  alfa-romero        std
# 2           2          1                122  alfa-romero        std
# 3           3          2                164         audi        std
# 4           4          2                164         audi        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %%
#Now converting dataframe into mysql database
eda.to_sql('automobile', con=conn, if_exists='replace')
